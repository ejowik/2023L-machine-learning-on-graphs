# %%
from math import ceil

import torch
import torch.nn.functional as F
from torch.nn import Linear

from torch_geometric.datasets import TUDataset
from torch_geometric.loader import DataLoader
from torch_geometric.nn import DenseGraphConv, GCNConv, dense_mincut_pool
from torch_geometric.utils import to_dense_adj, to_dense_batch

import sys

sys.path.append("../")
import utils

import torch

import torch
import torch.nn.functional as F
import torch_geometric as tg

from torch_geometric.loader import DataLoader
from sklearn.metrics import f1_score, accuracy_score
import numpy as np

train_dataset = utils.GraphDataset("../data/", "GunPoint", quantile=False)
train_loader = DataLoader(train_dataset, batch_size=50, shuffle=True)

test_dataset = utils.GraphDataset("../data/", "GunPoint", False, quantile=False)
test_loader = DataLoader(test_dataset, batch_size=len(test_dataset))
# Out:
# (50, 150)
# (150, 150)

# %%
class Net(torch.nn.Module):
    def __init__(self, in_channels, out_channels, hidden_channels=32):
        super().__init__()

        self.conv1 = GCNConv(in_channels, hidden_channels)
        num_nodes = 100
        self.pool1 = Linear(hidden_channels, num_nodes)

        self.conv2 = DenseGraphConv(hidden_channels, hidden_channels)
        num_nodes = ceil(2 / 3 * num_nodes)
        self.pool2 = Linear(hidden_channels, num_nodes)

        self.conv3 = DenseGraphConv(hidden_channels, hidden_channels)

        self.lin1 = Linear(hidden_channels, hidden_channels)
        self.lin2 = Linear(hidden_channels, out_channels)

    def forward(self, data):
        x, edge_index, batch, edge_weight = (
            data.x,
            data.edge_index,
            data.batch,
            data.edge_weight,
        )
        x = self.conv1(x, edge_index, edge_weight).relu()

        x, mask = to_dense_batch(x, batch)
        adj = to_dense_adj(edge_index, batch)
        s = self.pool1(x)
        x, adj, mc1, o1 = dense_mincut_pool(x, adj, s, mask)

        x = self.conv2(x, adj).relu()
        s = self.pool2(x)
        x, adj, mc2, o2 = dense_mincut_pool(x, adj, s)

        x = self.conv3(x, adj).relu()

        x = x.mean(dim=1)
        x = self.lin1(x).relu()
        x = self.lin2(x)
        return F.log_softmax(x, dim=-1), mc1 + mc2, o1 + o2

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = Net(13, 2).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %%
def train():
    model.train()

    total_loss = 0
    for data in train_loader:
        optimizer.zero_grad()
        y_out, mc_loss, o_loss = model(data)
        loss = F.nll_loss(y_out, data.y) + mc_loss + o_loss
        loss.backward()
        optimizer.step()
        total_loss += float(loss) * data.num_graphs
    return total_loss / len(train_loader.dataset)


@torch.no_grad()
def test(loader):
    model.eval()
    y_pred = []
    y_true = []
    loss = 0
    for data in loader:
        y_out, mc_loss, o_loss = model(data)
        y_pred.append(y_out.argmax(dim=-1))
        y_true.append(data.y)
        loss += float(F.nll_loss(y_out, data.y) * data.num_graphs + mc_loss + o_loss)
    y_pred = np.concatenate(y_pred)
    y_true = np.concatenate(y_true)
    return (
        f1_score(y_true=y_true, y_pred=y_pred, average="macro"),
        accuracy_score(y_true=y_true, y_pred=y_pred),
        loss / len(loader.dataset),
    )

# %%
best_macro_f1 = -1
train_losses = []
val_losses = []

# %%
import time

start = time.time()
for epoch in range(340):
    train()
    train_macro_f1, train_acc, train_loss = test(train_loader)
    test_macro_f1, test_acc, test_loss = test(test_loader)
    print(
        f"Epoch: {epoch:03d}, Train_Loss: {train_loss:02.4f},Test_Loss: {test_loss:02.4f},Train_f1: {train_macro_f1:01.4f},Test_f1: {test_macro_f1:01.4f},Train_acc: {train_acc:01.4f},Test_acc: {test_acc:01.4f}"
    )
    if test_macro_f1 > best_macro_f1:
        best_accuracy = test_macro_f1
        best_epoch = epoch
        torch.save(model.state_dict(), "../data/best_model.pth")
    train_losses.append(train_loss)
    val_losses.append(test_loss)
print(time.time() - start)
# Out:
# Epoch: 000, Train_Loss: 14.8525,Test_Loss: 13.3482,Train_f1: 0.3243,Test_f1: 0.3363,Train_acc: 0.4800,Test_acc: 0.5067
# Epoch:
# Epoch: 200, Train_Loss: 0.6518,Test_Loss: 0.6751,Train_f1: 0.5758,Test_f1: 0.6786,Train_acc: 0.5800,Test_acc: 0.6800
# Epoch: 201, Train_Loss: 0.6516,Test_Loss: 0.6752,Train_f1: 0.5758,Test_f1: 0.6786,Train_acc: 0.5800,Test_acc: 0.6800
# Epoch: 202, Train_Loss: 0.6514,Test_Loss: 0.6757,Train_f1: 0.5758,Test_f1: 0.6786,Train_acc: 0.5800,Test_acc: 0.6800
# Epoch: 203, Train_Loss: 0.6511,Test_Loss: 0.6753,Train_f1: 0.5758,Test_f1: 0.6786,Train_acc: 0.5800,Test_acc: 0.6800
# Epoch: 204, Train_Loss: 0.6508,Test_Loss: 0.6755,Train_f1: 0.5758,Test_f1: 0.6786,Train_acc: 0.5800,Test_acc: 0.6800
# Epoch: 205, Train_Loss: 0.6506,Test_Loss: 0.6761,Train_f1: 0.5758,Test_f1: 0.6786,Train_acc: 0.5800,Test_acc: 0.6800
# Epoch: 206, Train_Loss: 0.6503,Test_Loss: 0.6757,Train_f1: 0.5758,Test_f1: 0.6786,Train_acc: 0.5800,Test_acc: 0.6800
# Epoch: 207, Train_Loss: 0.6500,Test_Loss: 0.6759,Train_f1: 0.5758,Test_f1: 0.6786,Train_acc: 0.5800,Test_acc: 0.6800
# Epoch: 208, Train_Loss: 0.6499,Test_Loss: 0.6766,Train_f1: 0.5758,Test_f1: 0.6786,Train_acc: 0.5800,Test_acc: 0.6800
# Epoch: 209, Train_Loss: 0.6496,Test_Loss: 0.6763,Train_f1: 0.5758,Test_f1: 0.6786,Train_acc: 0.5800,Test_acc: 0.6800
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 5
#       3 for epoch in range(340):
#       4     train()
# ----> 5     train_macro_f1, train_acc, train_loss = test(train_loader)
#       6     test_macro_f1, test_acc, test_loss = test(test_loader)
#       7     print(
#       8         f"Epoch: {epoch:03d}, Train_Loss: {train_loss:02.4f},Test_Loss: {test_loss:02.4f},Train_f1: {train_macro_f1:01.4f},Test_f1: {test_macro_f1:01.4f},Train_acc: {train_acc:01.4f},Test_acc: {test_acc:01.4f}"
#       9     )
#
# File ~/venvs/MLG/lib/python3.9/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# Cell In[5], line 22, in test(loader)
#      20 loss = 0
#      21 for data in loader:
# ---> 22     y_out, mc_loss, o_loss = model(data)
#      23     y_pred.append(y_out.argmax(dim=-1))
#      24     y_true.append(data.y)
#
# File ~/venvs/MLG/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[3], line 30, in Net.forward(self, data)
#      28 adj = to_dense_adj(edge_index, batch)
#      29 s = self.pool1(x)
# ---> 30 x, adj, mc1, o1 = dense_mincut_pool(x, adj, s, mask)
#      32 x = self.conv2(x, adj).relu()
#      33 s = self.pool2(x)
#
# File ~/venvs/MLG/lib/python3.9/site-packages/torch_geometric/nn/dense/mincut_pool.py:86, in dense_mincut_pool(x, adj, s, mask, temp)
#      83 d_flat = torch.einsum('ijk->ij', adj)
#      84 d = _rank3_diag(d_flat)
#      85 mincut_den = _rank3_trace(
# ---> 86     torch.matmul(torch.matmul(s.transpose(1, 2), d), s))
#      87 mincut_loss = -(mincut_num / mincut_den)
#      88 mincut_loss = torch.mean(mincut_loss)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

plt.plot(train_losses)
plt.plot(val_losses)
plt.show()
