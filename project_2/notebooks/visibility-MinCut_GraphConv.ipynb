# %%
from math import ceil

import torch
import torch.nn.functional as F
from torch.nn import Linear

from torch_geometric.datasets import TUDataset
from torch_geometric.loader import DataLoader
from torch_geometric.nn import DenseGraphConv, GCNConv, dense_mincut_pool
from torch_geometric.utils import to_dense_adj, to_dense_batch

import sys

sys.path.append("../")
import utils

import torch

import torch
import torch.nn.functional as F
import torch_geometric as tg

from torch_geometric.loader import DataLoader
from sklearn.metrics import f1_score, accuracy_score
import numpy as np

train_dataset = utils.GraphDataset("../data/", "GunPoint", quantile=False)
train_loader = DataLoader(train_dataset, batch_size=50, shuffle=True)

test_dataset = utils.GraphDataset("../data/", "GunPoint", False, quantile=False)
test_loader = DataLoader(test_dataset, batch_size=len(test_dataset))


class Net(torch.nn.Module):
    def __init__(self, in_channels, out_channels, hidden_channels=32):
        super().__init__()

        self.conv1 = GCNConv(in_channels, hidden_channels)
        num_nodes = 100
        self.pool1 = Linear(hidden_channels, num_nodes)

        self.conv2 = DenseGraphConv(hidden_channels, hidden_channels)
        num_nodes = ceil(2 / 3 * num_nodes)
        self.pool2 = Linear(hidden_channels, num_nodes)

        self.conv3 = DenseGraphConv(hidden_channels, hidden_channels)

        self.lin1 = Linear(hidden_channels, hidden_channels)
        self.lin2 = Linear(hidden_channels, out_channels)

    def forward(self, data):
        x, edge_index, batch, edge_weight = (
            data.x,
            data.edge_index,
            data.batch,
            data.edge_weight,
        )
        x = self.conv1(x, edge_index, edge_weight).relu()

        x, mask = to_dense_batch(x, batch)
        adj = to_dense_adj(edge_index, batch)
        s = self.pool1(x)
        x, adj, mc1, o1 = dense_mincut_pool(x, adj, s, mask)

        x = self.conv2(x, adj).relu()
        s = self.pool2(x)
        x, adj, mc2, o2 = dense_mincut_pool(x, adj, s)

        x = self.conv3(x, adj).relu()

        x = x.mean(dim=1)
        x = self.lin1(x).relu()
        x = self.lin2(x)
        return F.log_softmax(x, dim=-1), mc1 + mc2, o1 + o2
# Out:
# (50, 150)
# (150, 150)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = Net(1, 2).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
def train():
    model.train()

    total_loss = 0
    for data in train_loader:
        optimizer.zero_grad()
        y_out, mc_loss, o_loss = model(data)
        loss = F.nll_loss(y_out, data.y) + mc_loss + o_loss
        loss.backward()
        optimizer.step()
        total_loss += float(loss) * data.num_graphs
    return total_loss / len(train_loader.dataset)


@torch.no_grad()
def test(loader):
    model.eval()
    y_pred = []
    y_true = []
    loss = 0
    for data in loader:
        y_out, mc_loss, o_loss = model(data)
        y_pred.append(y_out.argmax(dim=-1))
        y_true.append(data.y)
        loss += float(F.nll_loss(y_out, data.y) * data.num_graphs + mc_loss + o_loss)
    y_pred = np.concatenate(y_pred)
    y_true = np.concatenate(y_true)
    return (
        f1_score(y_true=y_true, y_pred=y_pred, average="macro"),
        accuracy_score(y_true=y_true, y_pred=y_pred),
        loss / len(loader.dataset),
    )

# %%
best_macro_f1 = -1

# %%
train_losses = []
val_losses = []
for epoch in range(120):
    train()
    train_macro_f1, train_acc, train_loss = test(train_loader)
    test_macro_f1, test_acc, test_loss = test(test_loader)
    print(
        f"Epoch: {epoch:03d}, Train_Loss: {train_loss:02.4f},Test_Loss: {test_loss:02.4f},Train_f1: {train_macro_f1:01.4f},Test_f1: {test_macro_f1:01.4f},Train_acc: {train_acc:01.4f},Test_acc: {test_acc:01.4f}"
    )
    if test_macro_f1 > best_macro_f1:
        best_accuracy = test_macro_f1
        best_epoch = epoch
        torch.save(model.state_dict(), "../data/best_model.pth")
    train_losses.append(train_loss)
    val_losses.append(test_loss)
# Out:
# Epoch: 000, Train_Loss: 0.7087,Test_Loss: 0.6973,Train_f1: 0.3243,Test_f1: 0.3363,Train_acc: 0.4800,Test_acc: 0.5067
# Epoch: 001, Train_Loss: 0.7079,Test_Loss: 0.6970,Train_f1: 0.3243,Test_f1: 0.3363,Train_acc: 0.4800,Test_acc: 0.5067
# Epoch: 002, Train_Loss: 0.7072,Test_Loss: 0.6967,Train_f1: 0.3243,Test_f1: 0.3363,Train_acc: 0.4800,Test_acc: 0.5067
# Epoch: 003, Train_Loss: 0.7065,Test_Loss: 0.6964,Train_f1: 0.3243,Test_f1: 0.3363,Train_acc: 0.4800,Test_acc: 0.5067
# Epoch: 004, Train_Loss: 0.7059,Test_Loss: 0.6963,Train_f1: 0.5091,Test_f1: 0.4665,Train_acc: 0.5800,Test_acc: 0.5667
# Epoch: 005, Train_Loss: 0.7054,Test_Loss: 0.6962,Train_f1: 0.4545,Test_f1: 0.5256,Train_acc: 0.4600,Test_acc: 0.5267
# Epoch: 006, Train_Loss: 0.7049,Test_Loss: 0.6961,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 007, Train_Loss: 0.7045,Test_Loss: 0.6961,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 008, Train_Loss: 0.7042,Test_Loss: 0.6962,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 009, Train_Loss: 0.7040,Test_Loss: 0.6963,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 010, Train_Loss: 0.7038,Test_Loss: 0.6965,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 011, Train_Loss: 0.7037,Test_Loss: 0.6967,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 012, Train_Loss: 0.7035,Test_Loss: 0.6968,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 013, Train_Loss: 0.7033,Test_Loss: 0.6968,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 014, Train_Loss: 0.7032,Test_Loss: 0.6968,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 015, Train_Loss: 0.7030,Test_Loss: 0.6967,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 016, Train_Loss: 0.7028,Test_Loss: 0.6966,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 017, Train_Loss: 0.7026,Test_Loss: 0.6964,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 018, Train_Loss: 0.7023,Test_Loss: 0.6961,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 019, Train_Loss: 0.7021,Test_Loss: 0.6958,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 020, Train_Loss: 0.7017,Test_Loss: 0.6954,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 021, Train_Loss: 0.7014,Test_Loss: 0.6950,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 022, Train_Loss: 0.7011,Test_Loss: 0.6946,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 023, Train_Loss: 0.7007,Test_Loss: 0.6941,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 024, Train_Loss: 0.7003,Test_Loss: 0.6937,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 025, Train_Loss: 0.6999,Test_Loss: 0.6932,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 026, Train_Loss: 0.6994,Test_Loss: 0.6927,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 027, Train_Loss: 0.6988,Test_Loss: 0.6921,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 028, Train_Loss: 0.6979,Test_Loss: 0.6913,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 029, Train_Loss: 0.6972,Test_Loss: 0.6905,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 030, Train_Loss: 0.6965,Test_Loss: 0.6899,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 031, Train_Loss: 0.6958,Test_Loss: 0.6892,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 032, Train_Loss: 0.6949,Test_Loss: 0.6884,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 033, Train_Loss: 0.6939,Test_Loss: 0.6875,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 034, Train_Loss: 0.6929,Test_Loss: 0.6866,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 035, Train_Loss: 0.6917,Test_Loss: 0.6855,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 036, Train_Loss: 0.6902,Test_Loss: 0.6842,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 037, Train_Loss: 0.6885,Test_Loss: 0.6828,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 038, Train_Loss: 0.6870,Test_Loss: 0.6813,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 039, Train_Loss: 0.6853,Test_Loss: 0.6796,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 040, Train_Loss: 0.6834,Test_Loss: 0.6778,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 041, Train_Loss: 0.6814,Test_Loss: 0.6758,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 042, Train_Loss: 0.6792,Test_Loss: 0.6737,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 043, Train_Loss: 0.6767,Test_Loss: 0.6712,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch: 044, Train_Loss: 0.6741,Test_Loss: 0.6686,Train_f1: 0.3421,Test_f1: 0.3590,Train_acc: 0.5200,Test_acc: 0.5067
# Epoch: 045, Train_Loss: 0.6712,Test_Loss: 0.6657,Train_f1: 0.3421,Test_f1: 0.3996,Train_acc: 0.5200,Test_acc: 0.5267
# Epoch: 046, Train_Loss: 0.6680,Test_Loss: 0.6625,Train_f1: 0.4283,Test_f1: 0.4378,Train_acc: 0.5600,Test_acc: 0.5467
# Epoch: 047, Train_Loss: 0.6644,Test_Loss: 0.6591,Train_f1: 0.4283,Test_f1: 0.5297,Train_acc: 0.5600,Test_acc: 0.6000
# Epoch: 048, Train_Loss: 0.6605,Test_Loss: 0.6553,Train_f1: 0.5386,Test_f1: 0.5658,Train_acc: 0.6200,Test_acc: 0.6200
# Epoch: 049, Train_Loss: 0.6563,Test_Loss: 0.6512,Train_f1: 0.5714,Test_f1: 0.6045,Train_acc: 0.6400,Test_acc: 0.6467
# Epoch: 050, Train_Loss: 0.6516,Test_Loss: 0.6467,Train_f1: 0.6026,Test_f1: 0.6410,Train_acc: 0.6600,Test_acc: 0.6733
# Epoch: 051, Train_Loss: 0.6467,Test_Loss: 0.6419,Train_f1: 0.6608,Test_f1: 0.6866,Train_acc: 0.7000,Test_acc: 0.7067
# Epoch: 052, Train_Loss: 0.6413,Test_Loss: 0.6368,Train_f1: 0.7396,Test_f1: 0.7029,Train_acc: 0.7600,Test_acc: 0.7200
# Epoch: 053, Train_Loss: 0.6355,Test_Loss: 0.6313,Train_f1: 0.7396,Test_f1: 0.7423,Train_acc: 0.7600,Test_acc: 0.7533
# Epoch: 054, Train_Loss: 0.6293,Test_Loss: 0.6253,Train_f1: 0.8108,Test_f1: 0.7652,Train_acc: 0.8200,Test_acc: 0.7733
# Epoch: 055, Train_Loss: 0.6224,Test_Loss: 0.6188,Train_f1: 0.8333,Test_f1: 0.7726,Train_acc: 0.8400,Test_acc: 0.7800
# Epoch: 056, Train_Loss: 0.6150,Test_Loss: 0.6117,Train_f1: 0.8333,Test_f1: 0.8020,Train_acc: 0.8400,Test_acc: 0.8067
# Epoch: 057, Train_Loss: 0.6072,Test_Loss: 0.6041,Train_f1: 0.8980,Test_f1: 0.8035,Train_acc: 0.9000,Test_acc: 0.8067
# Epoch: 058, Train_Loss: 0.5990,Test_Loss: 0.5961,Train_f1: 0.9394,Test_f1: 0.8251,Train_acc: 0.9400,Test_acc: 0.8267
# Epoch: 059, Train_Loss: 0.5903,Test_Loss: 0.5877,Train_f1: 0.9394,Test_f1: 0.8390,Train_acc: 0.9400,Test_acc: 0.8400
# Epoch: 060, Train_Loss: 0.5809,Test_Loss: 0.5787,Train_f1: 0.9394,Test_f1: 0.8527,Train_acc: 0.9400,Test_acc: 0.8533
# Epoch: 061, Train_Loss: 0.5708,Test_Loss: 0.5691,Train_f1: 0.9394,Test_f1: 0.8595,Train_acc: 0.9400,Test_acc: 0.8600
# Epoch: 062, Train_Loss: 0.5605,Test_Loss: 0.5594,Train_f1: 0.9394,Test_f1: 0.8595,Train_acc: 0.9400,Test_acc: 0.8600
# Epoch: 063, Train_Loss: 0.5498,Test_Loss: 0.5492,Train_f1: 0.9398,Test_f1: 0.8798,Train_acc: 0.9400,Test_acc: 0.8800
# Epoch: 064, Train_Loss: 0.5386,Test_Loss: 0.5388,Train_f1: 0.9398,Test_f1: 0.8933,Train_acc: 0.9400,Test_acc: 0.8933
# Epoch: 065, Train_Loss: 0.5268,Test_Loss: 0.5279,Train_f1: 0.9398,Test_f1: 0.8865,Train_acc: 0.9400,Test_acc: 0.8867
# Epoch: 066, Train_Loss: 0.5146,Test_Loss: 0.5167,Train_f1: 0.9398,Test_f1: 0.8865,Train_acc: 0.9400,Test_acc: 0.8867
# Epoch: 067, Train_Loss: 0.5018,Test_Loss: 0.5051,Train_f1: 0.9398,Test_f1: 0.8933,Train_acc: 0.9400,Test_acc: 0.8933
# Epoch: 068, Train_Loss: 0.4885,Test_Loss: 0.4932,Train_f1: 0.9599,Test_f1: 0.9000,Train_acc: 0.9600,Test_acc: 0.9000
# Epoch: 069, Train_Loss: 0.4748,Test_Loss: 0.4813,Train_f1: 0.9799,Test_f1: 0.8999,Train_acc: 0.9800,Test_acc: 0.9000
# Epoch: 070, Train_Loss: 0.4606,Test_Loss: 0.4692,Train_f1: 0.9799,Test_f1: 0.8932,Train_acc: 0.9800,Test_acc: 0.8933
# Epoch: 071, Train_Loss: 0.4464,Test_Loss: 0.4564,Train_f1: 0.9799,Test_f1: 0.8999,Train_acc: 0.9800,Test_acc: 0.9000
# Epoch: 072, Train_Loss: 0.4320,Test_Loss: 0.4445,Train_f1: 0.9799,Test_f1: 0.8999,Train_acc: 0.9800,Test_acc: 0.9000
# Epoch: 073, Train_Loss: 0.4175,Test_Loss: 0.4332,Train_f1: 0.9799,Test_f1: 0.9065,Train_acc: 0.9800,Test_acc: 0.9067
# Epoch: 074, Train_Loss: 0.4031,Test_Loss: 0.4196,Train_f1: 0.9799,Test_f1: 0.9132,Train_acc: 0.9800,Test_acc: 0.9133
# Epoch: 075, Train_Loss: 0.3886,Test_Loss: 0.4094,Train_f1: 0.9597,Test_f1: 0.9064,Train_acc: 0.9600,Test_acc: 0.9067
# Epoch: 076, Train_Loss: 0.3744,Test_Loss: 0.3984,Train_f1: 0.9394,Test_f1: 0.9131,Train_acc: 0.9400,Test_acc: 0.9133
# Epoch: 077, Train_Loss: 0.3602,Test_Loss: 0.3845,Train_f1: 0.9394,Test_f1: 0.9199,Train_acc: 0.9400,Test_acc: 0.9200
# Epoch: 078, Train_Loss: 0.3462,Test_Loss: 0.3765,Train_f1: 0.9394,Test_f1: 0.9131,Train_acc: 0.9400,Test_acc: 0.9133
# Epoch: 079, Train_Loss: 0.3322,Test_Loss: 0.3625,Train_f1: 0.9394,Test_f1: 0.9199,Train_acc: 0.9400,Test_acc: 0.9200
# Epoch: 080, Train_Loss: 0.3185,Test_Loss: 0.3532,Train_f1: 0.9394,Test_f1: 0.9131,Train_acc: 0.9400,Test_acc: 0.9133
# Epoch: 081, Train_Loss: 0.3050,Test_Loss: 0.3414,Train_f1: 0.9394,Test_f1: 0.9131,Train_acc: 0.9400,Test_acc: 0.9133
# Epoch: 082, Train_Loss: 0.2917,Test_Loss: 0.3273,Train_f1: 0.9394,Test_f1: 0.9199,Train_acc: 0.9400,Test_acc: 0.9200
# Epoch: 083, Train_Loss: 0.2788,Test_Loss: 0.3216,Train_f1: 0.9394,Test_f1: 0.9131,Train_acc: 0.9400,Test_acc: 0.9133
# Epoch: 084, Train_Loss: 0.2663,Test_Loss: 0.3039,Train_f1: 0.9597,Test_f1: 0.9132,Train_acc: 0.9600,Test_acc: 0.9133
# Epoch: 085, Train_Loss: 0.2540,Test_Loss: 0.2976,Train_f1: 0.9394,Test_f1: 0.9199,Train_acc: 0.9400,Test_acc: 0.9200
# Epoch: 086, Train_Loss: 0.2425,Test_Loss: 0.2883,Train_f1: 0.9394,Test_f1: 0.9199,Train_acc: 0.9400,Test_acc: 0.9200
# Epoch: 087, Train_Loss: 0.2316,Test_Loss: 0.2728,Train_f1: 0.9398,Test_f1: 0.9199,Train_acc: 0.9400,Test_acc: 0.9200
# Epoch: 088, Train_Loss: 0.2207,Test_Loss: 0.2718,Train_f1: 0.9394,Test_f1: 0.9132,Train_acc: 0.9400,Test_acc: 0.9133
# Epoch: 089, Train_Loss: 0.2104,Test_Loss: 0.2574,Train_f1: 0.9597,Test_f1: 0.9199,Train_acc: 0.9600,Test_acc: 0.9200
# Epoch: 090, Train_Loss: 0.2008,Test_Loss: 0.2493,Train_f1: 0.9398,Test_f1: 0.9199,Train_acc: 0.9400,Test_acc: 0.9200
# Epoch: 091, Train_Loss: 0.1920,Test_Loss: 0.2480,Train_f1: 0.9597,Test_f1: 0.9132,Train_acc: 0.9600,Test_acc: 0.9133
# Epoch: 092, Train_Loss: 0.1836,Test_Loss: 0.2334,Train_f1: 0.9398,Test_f1: 0.9199,Train_acc: 0.9400,Test_acc: 0.9200
# Epoch: 093, Train_Loss: 0.1756,Test_Loss: 0.2358,Train_f1: 0.9597,Test_f1: 0.9132,Train_acc: 0.9600,Test_acc: 0.9133
# Epoch: 094, Train_Loss: 0.1679,Test_Loss: 0.2236,Train_f1: 0.9398,Test_f1: 0.9199,Train_acc: 0.9400,Test_acc: 0.9200
# Epoch: 095, Train_Loss: 0.1607,Test_Loss: 0.2229,Train_f1: 0.9398,Test_f1: 0.9199,Train_acc: 0.9400,Test_acc: 0.9200
# Epoch: 096, Train_Loss: 0.1539,Test_Loss: 0.2177,Train_f1: 0.9398,Test_f1: 0.9199,Train_acc: 0.9400,Test_acc: 0.9200
# Epoch: 097, Train_Loss: 0.1478,Test_Loss: 0.2122,Train_f1: 0.9398,Test_f1: 0.9266,Train_acc: 0.9400,Test_acc: 0.9267
# Epoch: 098, Train_Loss: 0.1423,Test_Loss: 0.2137,Train_f1: 0.9597,Test_f1: 0.9199,Train_acc: 0.9600,Test_acc: 0.9200
# Epoch: 099, Train_Loss: 0.1373,Test_Loss: 0.2035,Train_f1: 0.9398,Test_f1: 0.9266,Train_acc: 0.9400,Test_acc: 0.9267
# Epoch: 100, Train_Loss: 0.1329,Test_Loss: 0.2127,Train_f1: 0.9597,Test_f1: 0.9199,Train_acc: 0.9600,Test_acc: 0.9200
# Epoch: 101, Train_Loss: 0.1290,Test_Loss: 0.1954,Train_f1: 0.9599,Test_f1: 0.9200,Train_acc: 0.9600,Test_acc: 0.9200
# Epoch: 102, Train_Loss: 0.1253,Test_Loss: 0.2127,Train_f1: 0.9597,Test_f1: 0.9132,Train_acc: 0.9600,Test_acc: 0.9133
# Epoch: 103, Train_Loss: 0.1209,Test_Loss: 0.1950,Train_f1: 0.9599,Test_f1: 0.9200,Train_acc: 0.9600,Test_acc: 0.9200
# Epoch: 104, Train_Loss: 0.1171,Test_Loss: 0.1993,Train_f1: 0.9398,Test_f1: 0.9266,Train_acc: 0.9400,Test_acc: 0.9267
# Epoch: 105, Train_Loss: 0.1144,Test_Loss: 0.2049,Train_f1: 0.9597,Test_f1: 0.9266,Train_acc: 0.9600,Test_acc: 0.9267
# Epoch: 106, Train_Loss: 0.1118,Test_Loss: 0.1918,Train_f1: 0.9800,Test_f1: 0.9133,Train_acc: 0.9800,Test_acc: 0.9133
# Epoch: 107, Train_Loss: 0.1087,Test_Loss: 0.2058,Train_f1: 0.9597,Test_f1: 0.9266,Train_acc: 0.9600,Test_acc: 0.9267
# Epoch: 108, Train_Loss: 0.1055,Test_Loss: 0.1977,Train_f1: 0.9800,Test_f1: 0.9266,Train_acc: 0.9800,Test_acc: 0.9267
# Epoch: 109, Train_Loss: 0.1034,Test_Loss: 0.1956,Train_f1: 0.9800,Test_f1: 0.9200,Train_acc: 0.9800,Test_acc: 0.9200
# Epoch: 110, Train_Loss: 0.1016,Test_Loss: 0.2060,Train_f1: 0.9597,Test_f1: 0.9266,Train_acc: 0.9600,Test_acc: 0.9267
# Epoch: 111, Train_Loss: 0.0995,Test_Loss: 0.1930,Train_f1: 0.9800,Test_f1: 0.9133,Train_acc: 0.9800,Test_acc: 0.9133
# Epoch: 112, Train_Loss: 0.0971,Test_Loss: 0.2022,Train_f1: 0.9799,Test_f1: 0.9266,Train_acc: 0.9800,Test_acc: 0.9267
# Epoch: 113, Train_Loss: 0.0950,Test_Loss: 0.1999,Train_f1: 0.9800,Test_f1: 0.9266,Train_acc: 0.9800,Test_acc: 0.9267
# Epoch: 114, Train_Loss: 0.0935,Test_Loss: 0.1955,Train_f1: 0.9800,Test_f1: 0.9133,Train_acc: 0.9800,Test_acc: 0.9133
# Epoch: 115, Train_Loss: 0.0921,Test_Loss: 0.2073,Train_f1: 0.9799,Test_f1: 0.9266,Train_acc: 0.9800,Test_acc: 0.9267
# Epoch: 116, Train_Loss: 0.0904,Test_Loss: 0.1957,Train_f1: 0.9800,Test_f1: 0.9133,Train_acc: 0.9800,Test_acc: 0.9133
# Epoch: 117, Train_Loss: 0.0884,Test_Loss: 0.2065,Train_f1: 1.0000,Test_f1: 0.9266,Train_acc: 1.0000,Test_acc: 0.9267
# Epoch: 118, Train_Loss: 0.0867,Test_Loss: 0.2028,Train_f1: 0.9800,Test_f1: 0.9200,Train_acc: 0.9800,Test_acc: 0.9200
# Epoch: 119, Train_Loss: 0.0852,Test_Loss: 0.2026,Train_f1: 0.9800,Test_f1: 0.9133,Train_acc: 0.9800,Test_acc: 0.9133

# %%
import matplotlib.pyplot as plt

plt.plot(train_losses)
plt.plot(val_losses)
plt.show()
