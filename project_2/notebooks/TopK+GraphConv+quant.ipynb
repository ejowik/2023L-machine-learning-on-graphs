# %%
import os.path as osp

import torch
import torch.nn.functional as F

from torch_geometric.datasets import TUDataset
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GraphConv, TopKPooling
from torch_geometric.nn import global_max_pool as gmp
from torch_geometric.nn import global_mean_pool as gap
import sys
from sklearn.metrics import f1_score, accuracy_score
import numpy as np

sys.path.append("../")
import utils

train_dataset = utils.GraphDataset("../data/", "GunPoint", n_quantiles=35)
train_loader = DataLoader(train_dataset, batch_size=50, shuffle=True)

test_dataset = utils.GraphDataset("../data/", "GunPoint", False, n_quantiles=35)
test_loader = DataLoader(test_dataset, batch_size=int(len(test_dataset) / 2) + 1)


class Net(torch.nn.Module):
    def __init__(self):
        super().__init__()

        self.conv1 = GraphConv(1, 16)
        self.pool1 = TopKPooling(16, ratio=0.7)
        self.conv2 = GraphConv(16, 16)
        self.pool2 = TopKPooling(16, ratio=0.7)
        self.conv3 = GraphConv(16, 16)
        self.pool3 = TopKPooling(16, ratio=0.7)

        self.lin1 = torch.nn.Linear(32, 16)
        self.lin2 = torch.nn.Linear(16, 16)
        self.lin3 = torch.nn.Linear(16, 2)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch

        x = F.relu(self.conv1(x, edge_index))
        x, edge_index, _, batch, _, _ = self.pool1(x, edge_index, None, batch)
        x1 = torch.cat([gmp(x, batch), gap(x, batch)], dim=1)

        x = F.relu(self.conv2(x, edge_index))
        x, edge_index, _, batch, _, _ = self.pool2(x, edge_index, None, batch)
        x2 = torch.cat([gmp(x, batch), gap(x, batch)], dim=1)

        x = F.relu(self.conv3(x, edge_index))
        x, edge_index, _, batch, _, _ = self.pool3(x, edge_index, None, batch)
        x3 = torch.cat([gmp(x, batch), gap(x, batch)], dim=1)

        x = x1 + x2 + x3

        x = F.relu(self.lin1(x))
        x = F.dropout(x, p=0.5, training=self.training)
        x = F.relu(self.lin2(x))
        x = F.log_softmax(self.lin3(x), dim=-1)

        return x


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = Net().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, patience=5, mode="min", cooldown=2, factor=0.5, verbose=True
)
# Out:
# (50, 150)
# (150, 150)

# %%
def train():
    model.train()

    total_loss = 0
    for data in train_loader:
        optimizer.zero_grad()
        y_out = model(data)
        loss = F.nll_loss(y_out, data.y)
        loss.backward()
        optimizer.step()
        total_loss += float(loss) * data.num_graphs
    return total_loss / len(train_loader.dataset)


@torch.no_grad()
def test(loader):
    model.eval()
    y_pred = []
    y_true = []
    loss = 0
    for data in loader:
        y_out = model(data)
        y_pred.append(y_out.argmax(dim=-1))
        y_true.append(data.y)
        loss += float(F.nll_loss(y_out, data.y) * data.num_graphs)
    y_pred = np.concatenate(y_pred)
    y_true = np.concatenate(y_true)
    return (
        f1_score(y_true=y_true, y_pred=y_pred, average="macro"),
        accuracy_score(y_true=y_true, y_pred=y_pred),
        loss / len(loader.dataset),
    )


best_val_acc = test_acc = 0
best_val_loss = float("inf")
patience = start_patience = 50
best_macro_f1 = -1

# %%
train_losses = []
val_losses = []
for epoch in range(1, 1001):
    train()
    train_macro_f1, train_acc, train_loss = test(train_loader)
    test_macro_f1, test_acc, test_loss = test(test_loader)
    scheduler.step(train_loss)
    print(
        f"Epoch: {epoch:03d}, Train_Loss: {train_loss:02.4f},Test_Loss: {test_loss:02.4f},Train_f1: {train_macro_f1:01.4f},Test_f1: {test_macro_f1:01.4f},Train_acc: {train_acc:01.4f},Test_acc: {test_acc:01.4f}"
    )
    if test_macro_f1 > best_macro_f1:
        best_accuracy = test_macro_f1
        best_epoch = epoch
        torch.save(model.state_dict(), "../data/best_model.pth")
    train_losses.append(train_loss)
    val_losses.append(test_loss)
# Out:
# Epoch: 001, Train_Loss: 0.6967,Test_Loss: 0.7077,Train_f1: 0.3421,Test_f1: 0.3304,Train_acc: 0.5200,Test_acc: 0.4933
# Epoch:
Train_f1: 0.7778,Test_f1: 0.6346,Train_acc: 0.7800,Test_acc: 0.6533
# Epoch: 218, Train_Loss: 0.5138,Test_Loss: 0.5731,Train_f1: 0.7778,Test_f1: 0.6346,Train_acc: 0.7800,Test_acc: 0.6533
# Epoch: 219, Train_Loss: 0.5138,Test_Loss: 0.5731,Train_f1: 0.7778,Test_f1: 0.6346,Train_acc: 0.7800,Test_acc: 0.6533
# Epoch: 220, Train_Loss: 0.5138,Test_Loss: 0.5731,Train_f1: 0.7778,Test_f1: 0.6346,Train_acc: 0.7800,Test_acc: 0.6533
# Epoch: 221, Train_Loss: 0.5138,Test_Loss: 0.5731,Train_f1: 0.7778,Test_f1: 0.6346,Train_acc: 0.7800,Test_acc: 0.6533
# Epoch: 222, Train_Loss: 0.5138,Test_Loss: 0.5732,Train_f1: 0.7778,Test_f1: 0.6346,Train_acc: 0.7800,Test_acc: 0.6533
# Epoch: 223, Train_Loss: 0.5137,Test_Loss: 0.5732,Train_f1: 0.7778,Test_f1: 0.6346,Train_acc: 0.7800,Test_acc: 0.6533
# Epoch: 224, Train_Loss: 0.5136,Test_Loss: 0.5732,Train_f1: 0.7778,Test_f1: 0.6346,Train_acc: 0.7800,Test_acc: 0.6533
# Epoch: 225, Train_Loss: 0.5136,Test_Loss: 0.5732,Train_f1: 0.7778,Test_f1: 0.6346,Train_acc: 0.7800,Test_acc: 0.6533
# Epoch: 226, Train_Loss: 0.5136,Test_Loss: 0.5732,Train_f1: 0.7778,Test_f1: 0.6346,Train_acc: 0.7800,Test_acc: 0.6533
# Epoch: 227, Train_Loss: 0.5136,Test_Loss: 0.5731,Train_f1: 0.7778,Test_f1: 0.6346,Train_acc: 0.7800,Test_acc: 0.6533
# Epoch: 228, Train_Loss: 0.5136,Test_Loss: 0.5730,Train_f1: 0.7778,Test_f1: 0.6346,Train_acc: 0.7800,Test_acc: 0.6533
# Epoch: 229, Train_Loss: 0.5136,Test_Loss: 0.5729,Train_f1: 0.7778,Test_f1: 0.6346,Train_acc: 0.7800,Test_acc: 0.6533
# Epoch: 230, Train_Loss: 0.5136,Test_Loss: 0.5728,Train_f1: 0.7778,Test_f1: 0.6346,Train_acc: 0.7800,Test_acc: 0.6533
# Epoch: 231, Train_Loss: 0.5137,Test_Loss: 0.5727,Train_f1: 0.7778,Test_f1: 0.6346,Train_acc: 0.7800,Test_acc: 0.6533
# Epoch: 232, Train_Loss: 0.5138,Test_Loss: 0.5725,Train_f1: 0.7778,Test_f1: 0.6346,Train_acc: 0.7800,Test_acc: 0.6533
# Epoch 00233: reducing learning rate of group 0 to 7.8125e-06.
# Epoch: 233, Train_Loss: 0.5137,Test_Loss: 0.5723,Train_f1: 0.7778,Test_f1: 0.6346,Train_acc: 0.7800,Test_acc: 0.6533
# Epoch: 234, Train_Loss: 0.5137,Test_Loss: 0.5723,Train_f1: 0.7778,Test_f1: 0.6346,Train_acc: 0.7800,Test_acc: 0.6533
# Epoch: 235, Train_Loss: 0.5136,Test_Loss: 0.5722,Train_f1: 0.7778,Test_f1: 0.6346,Train_acc: 0.7800,Test_acc: 0.6533
# Epoch: 236, Train_Loss: 0.5136,Test_Loss: 0.5722,Train_f1: 0.7778,Test_f1: 0.6427,Train_acc: 0.7800,Test_acc: 0.6600
# Epoch: 237, Train_Loss: 0.5134,Test_Loss: 0.5722,Train_f1: 0.7778,Test_f1: 0.6427,Train_acc: 0.7800,Test_acc: 0.6600
# Epoch: 238, Train_Loss: 0.5134,Test_Loss: 0.5722,Train_f1: 0.7778,Test_f1: 0.6427,Train_acc: 0.7800,Test_acc: 0.6600
# Epoch: 239, Train_Loss: 0.5133,Test_Loss: 0.5722,Train_f1: 0.7778,Test_f1: 0.6427,Train_acc: 0.7800,Test_acc: 0.6600
# Epoch: 240, Train_Loss: 0.5133,Test_Loss: 0.5721,Train_f1: 0.7778,Test_f1: 0.6427,Train_acc: 0.7800,Test_acc: 0.6600
# Epoch: 241, Train_Loss: 0.5136,Test_Loss: 0.5722,Train_f1: 0.7778,Test_f1: 0.6427,Train_acc: 0.7800,Test_acc: 0.6600
# Epoch: 242, Train_Loss: 0.5135,Test_Loss: 0.5722,Train_f1: 0.7778,Test_f1: 0.6427,Train_acc: 0.7800,Test_acc: 0.6600
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 5
#       3 for epoch in range(1, 1001):
#       4     train()
# ----> 5     train_macro_f1, train_acc, train_loss = test(train_loader)
#       6     test_macro_f1, test_acc, test_loss = test(test_loader)
#       7     scheduler.step(train_loss)
#
# File ~/venvs/MLG/lib/python3.9/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# Cell In[9], line 21, in test(loader)
#      19 y_true = []
#      20 loss = 0
# ---> 21 for data in loader:
#      22     y_out= model(data)
#      23     y_pred.append(y_out.argmax(dim=-1))
#
# File ~/venvs/MLG/lib/python3.9/site-packages/torch/utils/data/dataloader.py:634, in _BaseDataLoaderIter.__next__(self)
#     631 if self._sampler_iter is None:
#     632     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     633     self._reset()  # type: ignore[call-arg]
# --> 634 data = self._next_data()
#     635 self._num_yielded += 1
#     636 if self._dataset_kind == _DatasetKind.Iterable and \
#     637         self._IterableDataset_len_called is not None and \
#     638         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/venvs/MLG/lib/python3.9/site-packages/torch/utils/data/dataloader.py:678, in _SingleProcessDataLoaderIter._next_data(self)
#     676 def _next_data(self):
#     677     index = self._next_index()  # may raise StopIteration
# --> 678     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     679     if self._pin_memory:
#     680         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/venvs/MLG/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:54, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
# ---> 54 return self.collate_fn(data)
#
# File ~/venvs/MLG/lib/python3.9/site-packages/torch_geometric/loader/dataloader.py:20, in Collater.__call__(self, batch)
#      18 elem = batch[0]
#      19 if isinstance(elem, BaseData):
# ---> 20     return Batch.from_data_list(batch, self.follow_batch,
#      21                                 self.exclude_keys)
#      22 elif isinstance(elem, torch.Tensor):
#      23     return default_collate(batch)
#
# File ~/venvs/MLG/lib/python3.9/site-packages/torch_geometric/data/batch.py:76, in Batch.from_data_list(cls, data_list, follow_batch, exclude_keys)
#      64 @classmethod
#      65 def from_data_list(cls, data_list: List[BaseData],
#      66                    follow_batch: Optional[List[str]] = None,
#      67                    exclude_keys: Optional[List[str]] = None):
#      68     r"""Constructs a :class:`~torch_geometric.data.Batch` object from a
#      69     Python list of :class:`~torch_geometric.data.Data` or
#      70     :class:`~torch_geometric.data.HeteroData` objects.
#    (...)
#      73     :obj:`follow_batch`.
#      74     Will exclude any keys given in :obj:`exclude_keys`."""
# ---> 76     batch, slice_dict, inc_dict = collate(
#      77         cls,
#      78         data_list=data_list,
#      79         increment=True,
#      80         add_batch=not isinstance(data_list[0], Batch),
#      81         follow_batch=follow_batch,
#      82         exclude_keys=exclude_keys,
#      83     )
#      85     batch._num_graphs = len(data_list)
#      86     batch._slice_dict = slice_dict
#
# File ~/venvs/MLG/lib/python3.9/site-packages/torch_geometric/data/collate.py:108, in collate(cls, data_list, increment, add_batch, follow_batch, exclude_keys)
#     105     if (add_batch and isinstance(stores[0], NodeStorage)
#     106             and stores[0].can_infer_num_nodes):
#     107         repeats = [store.num_nodes for store in stores]
# --> 108         out_store.batch = repeat_interleave(repeats, device=device)
#     109         out_store.ptr = cumsum(torch.tensor(repeats, device=device))
#     111 return out, slice_dict, inc_dict
#
# File ~/venvs/MLG/lib/python3.9/site-packages/torch_geometric/data/collate.py:247, in repeat_interleave(repeats, device)
#     243 def repeat_interleave(
#     244     repeats: List[int],
#     245     device: Optional[torch.device] = None,
#     246 ) -> Tensor:
# --> 247     outs = [torch.full((n, ), i, device=device) for i, n in enumerate(repeats)]
#     248     return torch.cat(outs, dim=0)
#
# File ~/venvs/MLG/lib/python3.9/site-packages/torch_geometric/data/collate.py:247, in <listcomp>(.0)
#     243 def repeat_interleave(
#     244     repeats: List[int],
#     245     device: Optional[torch.device] = None,
#     246 ) -> Tensor:
# --> 247     outs = [torch.full((n, ), i, device=device) for i, n in enumerate(repeats)]
#     248     return torch.cat(outs, dim=0)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

plt.plot(train_losses)
plt.plot(val_losses)
plt.show()

# %%
for elem in train_loader:
    break

# %%
elem
# Out:
# DataBatch(x=[1750, 1], edge_index=[2, 5297], weight=[5297], y=[50], edge_weight=[5297, 1], batch=[1750], ptr=[51])
