# %%
import os.path as osp

import torch
import torch.nn.functional as F

import torch_geometric as tg
from torch_geometric.datasets import TUDataset
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GraphConv, TopKPooling
from torch_geometric.nn import global_max_pool as gmp
from torch_geometric.nn import global_mean_pool as gap
import sys
from sklearn.metrics import f1_score, accuracy_score
import numpy as np

sys.path.append("../")
import utils
import warnings

warnings.filterwarnings("ignore")

# %%
train_dataset = utils.GraphDataset("../data/", "GunPoint", True, n_quantiles=40)
train_loader = DataLoader(train_dataset, batch_size=50, shuffle=True)

test_dataset = utils.GraphDataset("../data/", "GunPoint", False, n_quantiles=40)
test_loader = DataLoader(test_dataset, batch_size=len(test_dataset))
for elem in train_dataset:
    break
elem
# Out:
# (50, 150)
# (150, 150)
# Data(edge_index=[2, 121], weight=[121], x=[40, 13], y=1, edge_attr=[121, 1])

# %%
class Net(torch.nn.Module):
    def __init__(self, in_features, hidden_channels=12, ratio=0.8):
        super().__init__()
        nn = tg.nn.MLP([in_features, hidden_channels])
        self.conv1 = tg.nn.GINEConv(nn, edge_dim=1)
        self.pool1 = TopKPooling(hidden_channels, ratio=ratio)
        nn = tg.nn.MLP([hidden_channels, hidden_channels])
        self.conv2 = tg.nn.GINEConv(nn, edge_dim=1)
        self.pool2 = TopKPooling(hidden_channels, ratio=ratio)
        nn = tg.nn.MLP([hidden_channels, hidden_channels])
        self.conv3 = tg.nn.GINEConv(nn, edge_dim=1)
        self.pool3 = TopKPooling(hidden_channels, ratio=ratio)

        self.lin1 = torch.nn.Linear(2 * hidden_channels, 16)
        self.lin2 = torch.nn.Linear(16, 8)
        self.lin3 = torch.nn.Linear(8, 2)

    def forward(self, data):
        x, edge_index, batch, edge_attr = (
            data.x,
            data.edge_index,
            data.batch,
            data.edge_attr,
        )

        x = F.relu(self.conv1(x, edge_index, edge_attr))
        x, edge_index, edge_attr, batch, _, _ = self.pool1(
            x, edge_index, edge_attr, batch
        )
        x1 = torch.cat([gmp(x, batch), gap(x, batch)], dim=1)

        x = F.relu(self.conv2(x, edge_index, edge_attr))
        x, edge_index, edge_attr, batch, _, _ = self.pool2(
            x, edge_index, edge_attr, batch
        )
        x2 = torch.cat([gmp(x, batch), gap(x, batch)], dim=1)

        x = F.relu(self.conv3(x, edge_index, edge_attr))
        x, edge_index, edge_attr, batch, _, _ = self.pool3(
            x, edge_index, edge_attr, batch
        )
        x3 = torch.cat([gmp(x, batch), gap(x, batch)], dim=1)

        x = x1 + x2 + x3

        x = F.relu(self.lin1(x))
        x = F.dropout(x, p=0.3, training=self.training)
        x = F.relu(self.lin2(x))
        x = F.log_softmax(self.lin3(x), dim=-1)

        return x

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = Net(13, hidden_channels=16).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)
# scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
#     optimizer, patience=5, mode="min", cooldown=2, factor=0.5, verbose=True
# )

# %%
def train():
    model.train()

    total_loss = 0
    for data in train_loader:
        optimizer.zero_grad()
        y_out = model(data)
        loss = F.nll_loss(y_out, data.y)
        loss.backward()
        optimizer.step()
        total_loss += float(loss) * data.num_graphs
    return total_loss / len(train_loader.dataset)


@torch.no_grad()
def test(loader):
    model.eval()
    y_pred = []
    y_true = []
    loss = 0
    for data in loader:
        y_out = model(data)
        y_pred.append(y_out.argmax(dim=-1))
        y_true.append(data.y)
        loss += float(F.nll_loss(y_out, data.y) * data.num_graphs)
    y_pred = np.concatenate(y_pred)
    y_true = np.concatenate(y_true)
    return (
        f1_score(y_true=y_true, y_pred=y_pred, average="macro"),
        accuracy_score(y_true=y_true, y_pred=y_pred),
        loss / len(loader.dataset),
    )

# %%
best_macro_f1 = -1
train_losses = []
val_losses = []
for epoch in range(250):
    train()
    train_macro_f1, train_acc, train_loss = test(train_loader)
    test_macro_f1, test_acc, test_loss = test(test_loader)
    # scheduler.step(train_loss)
    print(
        f"Epoch: {epoch:03d}, Train_Loss: {train_loss:02.4f},Test_Loss: {test_loss:02.4f},Train_f1: {train_macro_f1:01.4f},Test_f1: {test_macro_f1:01.4f},Train_acc: {train_acc:01.4f},Test_acc: {test_acc:01.4f}"
    )
    if test_macro_f1 > best_macro_f1:
        best_accuracy = test_macro_f1
        best_epoch = epoch
        torch.save(model.state_dict(), "../data/best_model.pth")
    train_losses.append(train_loss)
    val_losses.append(test_loss)
# Out:
# Epoch: 000, Train_Loss: 0.9899,Test_Loss: 1.0479,Train_f1: 0.4945,Test_f1: 0.5290,Train_acc: 0.5600,Test_acc: 0.5733
# Epoch: 001, Train_Loss: 0.9752,Test_Loss: 1.0399,Train_f1: 0.5251,Test_f1: 0.5332,Train_acc: 0.5800,Test_acc: 0.5733
# Epoch: 002, Train_Loss: 0.9581,Test_Loss: 1.0360,Train_f1: 0.5544,Test_f1: 0.5550,Train_acc: 0.6000,Test_acc: 0.5867
# Epoch: 003, Train_Loss: 0.9260,Test_Loss: 1.0261,Train_f1: 0.5544,Test_f1: 0.5605,Train_acc: 0.6000,Test_acc: 0.5933
# Epoch: 004, Train_Loss: 0.9212,Test_Loss: 1.0141,Train_f1: 0.5544,Test_f1: 0.5694,Train_acc: 0.6000,Test_acc: 0.6000
# Epoch: 005, Train_Loss: 0.8982,Test_Loss: 0.9963,Train_f1: 0.5385,Test_f1: 0.5694,Train_acc: 0.5800,Test_acc: 0.6000
# Epoch: 006, Train_Loss: 0.9205,Test_Loss: 1.0091,Train_f1: 0.5544,Test_f1: 0.5660,Train_acc: 0.6000,Test_acc: 0.6000
# Epoch: 007, Train_Loss: 0.9540,Test_Loss: 1.0193,Train_f1: 0.5251,Test_f1: 0.5623,Train_acc: 0.5800,Test_acc: 0.6000
# Epoch: 008, Train_Loss: 0.9396,Test_Loss: 0.9935,Train_f1: 0.5251,Test_f1: 0.5531,Train_acc: 0.5800,Test_acc: 0.5933
# Epoch: 009, Train_Loss: 0.9008,Test_Loss: 0.9500,Train_f1: 0.5251,Test_f1: 0.5385,Train_acc: 0.5800,Test_acc: 0.5800
# Epoch: 010, Train_Loss: 0.8229,Test_Loss: 0.8845,Train_f1: 0.5824,Test_f1: 0.5370,Train_acc: 0.6200,Test_acc: 0.5733
# Epoch: 011, Train_Loss: 0.7863,Test_Loss: 0.8594,Train_f1: 0.5824,Test_f1: 0.5226,Train_acc: 0.6200,Test_acc: 0.5600
# Epoch: 012, Train_Loss: 0.7665,Test_Loss: 0.8481,Train_f1: 0.5544,Test_f1: 0.5290,Train_acc: 0.6000,Test_acc: 0.5733
# Epoch: 013, Train_Loss: 0.7282,Test_Loss: 0.8241,Train_f1: 0.5544,Test_f1: 0.5343,Train_acc: 0.6000,Test_acc: 0.5800
# Epoch: 014, Train_Loss: 0.7162,Test_Loss: 0.8188,Train_f1: 0.5544,Test_f1: 0.5448,Train_acc: 0.6000,Test_acc: 0.5933
# Epoch: 015, Train_Loss: 0.7091,Test_Loss: 0.8189,Train_f1: 0.5544,Test_f1: 0.5553,Train_acc: 0.6000,Test_acc: 0.6067
# Epoch: 016, Train_Loss: 0.7129,Test_Loss: 0.8265,Train_f1: 0.5703,Test_f1: 0.5454,Train_acc: 0.6200,Test_acc: 0.6000
# Epoch: 017, Train_Loss: 0.7051,Test_Loss: 0.8299,Train_f1: 0.5703,Test_f1: 0.5353,Train_acc: 0.6200,Test_acc: 0.5933
# Epoch: 018, Train_Loss: 0.6759,Test_Loss: 0.8144,Train_f1: 0.5544,Test_f1: 0.5353,Train_acc: 0.6000,Test_acc: 0.5933
# Epoch: 019, Train_Loss: 0.6578,Test_Loss: 0.8044,Train_f1: 0.5544,Test_f1: 0.5500,Train_acc: 0.6000,Test_acc: 0.6000
# Epoch: 020, Train_Loss: 0.6412,Test_Loss: 0.7894,Train_f1: 0.5824,Test_f1: 0.5491,Train_acc: 0.6200,Test_acc: 0.5933
# Epoch: 021, Train_Loss: 0.6358,Test_Loss: 0.7811,Train_f1: 0.6353,Test_f1: 0.5395,Train_acc: 0.6600,Test_acc: 0.5867
# Epoch: 022, Train_Loss: 0.6336,Test_Loss: 0.7758,Train_f1: 0.6427,Test_f1: 0.5638,Train_acc: 0.6600,Test_acc: 0.6067
# Epoch: 023, Train_Loss: 0.6455,Test_Loss: 0.7830,Train_f1: 0.6604,Test_f1: 0.5350,Train_acc: 0.6800,Test_acc: 0.5867
# Epoch: 024, Train_Loss: 0.6480,Test_Loss: 0.7852,Train_f1: 0.6094,Test_f1: 0.5350,Train_acc: 0.6400,Test_acc: 0.5867
# Epoch: 025, Train_Loss: 0.6478,Test_Loss: 0.7882,Train_f1: 0.6094,Test_f1: 0.5251,Train_acc: 0.6400,Test_acc: 0.5800
# Epoch: 026, Train_Loss: 0.6459,Test_Loss: 0.7898,Train_f1: 0.6094,Test_f1: 0.5151,Train_acc: 0.6400,Test_acc: 0.5733
# Epoch: 027, Train_Loss: 0.6400,Test_Loss: 0.7866,Train_f1: 0.6094,Test_f1: 0.5151,Train_acc: 0.6400,Test_acc: 0.5733
# Epoch: 028, Train_Loss: 0.6329,Test_Loss: 0.7808,Train_f1: 0.6353,Test_f1: 0.5385,Train_acc: 0.6600,Test_acc: 0.5800
# Epoch: 029, Train_Loss: 0.6330,Test_Loss: 0.7793,Train_f1: 0.6604,Test_f1: 0.5332,Train_acc: 0.6800,Test_acc: 0.5733
# Epoch: 030, Train_Loss: 0.6458,Test_Loss: 0.7856,Train_f1: 0.6528,Test_f1: 0.5050,Train_acc: 0.6800,Test_acc: 0.5600
# Epoch: 031, Train_Loss: 0.6518,Test_Loss: 0.7873,Train_f1: 0.6528,Test_f1: 0.5050,Train_acc: 0.6800,Test_acc: 0.5600
# Epoch: 032, Train_Loss: 0.6467,Test_Loss: 0.7798,Train_f1: 0.6528,Test_f1: 0.5749,Train_acc: 0.6800,Test_acc: 0.6067
# Epoch: 033, Train_Loss: 0.6422,Test_Loss: 0.7749,Train_f1: 0.6180,Test_f1: 0.5749,Train_acc: 0.6400,Test_acc: 0.6067
# Epoch: 034, Train_Loss: 0.6355,Test_Loss: 0.7698,Train_f1: 0.6427,Test_f1: 0.5558,Train_acc: 0.6600,Test_acc: 0.5800
# Epoch: 035, Train_Loss: 0.6283,Test_Loss: 0.7652,Train_f1: 0.6486,Test_f1: 0.5717,Train_acc: 0.6600,Test_acc: 0.5867
# Epoch: 036, Train_Loss: 0.6177,Test_Loss: 0.7609,Train_f1: 0.6970,Test_f1: 0.5867,Train_acc: 0.7000,Test_acc: 0.5933
# Epoch: 037, Train_Loss: 0.6069,Test_Loss: 0.7586,Train_f1: 0.7585,Test_f1: 0.5623,Train_acc: 0.7600,Test_acc: 0.5667
# Epoch: 038, Train_Loss: 0.5933,Test_Loss: 0.7561,Train_f1: 0.7997,Test_f1: 0.5768,Train_acc: 0.8000,Test_acc: 0.5800
# Epoch: 039, Train_Loss: 0.5823,Test_Loss: 0.7544,Train_f1: 0.7997,Test_f1: 0.5798,Train_acc: 0.8000,Test_acc: 0.5800
# Epoch: 040, Train_Loss: 0.5749,Test_Loss: 0.7541,Train_f1: 0.7997,Test_f1: 0.5999,Train_acc: 0.8000,Test_acc: 0.6000
# Epoch: 041, Train_Loss: 0.5718,Test_Loss: 0.7532,Train_f1: 0.7600,Test_f1: 0.5933,Train_acc: 0.7600,Test_acc: 0.5933
# Epoch: 042, Train_Loss: 0.5726,Test_Loss: 0.7538,Train_f1: 0.7196,Test_f1: 0.5999,Train_acc: 0.7200,Test_acc: 0.6000
# Epoch: 043, Train_Loss: 0.5762,Test_Loss: 0.7586,Train_f1: 0.6970,Test_f1: 0.6037,Train_acc: 0.7000,Test_acc: 0.6067
# Epoch: 044, Train_Loss: 0.5826,Test_Loss: 0.7686,Train_f1: 0.6486,Test_f1: 0.5694,Train_acc: 0.6600,Test_acc: 0.5867
# Epoch: 045, Train_Loss: 0.5854,Test_Loss: 0.7729,Train_f1: 0.6486,Test_f1: 0.5670,Train_acc: 0.6600,Test_acc: 0.5867
# Epoch: 046, Train_Loss: 0.5850,Test_Loss: 0.7740,Train_f1: 0.6486,Test_f1: 0.5670,Train_acc: 0.6600,Test_acc: 0.5867
# Epoch: 047, Train_Loss: 0.5821,Test_Loss: 0.7741,Train_f1: 0.6486,Test_f1: 0.5670,Train_acc: 0.6600,Test_acc: 0.5867
# Epoch: 048, Train_Loss: 0.5729,Test_Loss: 0.7700,Train_f1: 0.6716,Test_f1: 0.5699,Train_acc: 0.6800,Test_acc: 0.5800
# Epoch: 049, Train_Loss: 0.5601,Test_Loss: 0.7630,Train_f1: 0.6989,Test_f1: 0.5994,Train_acc: 0.7000,Test_acc: 0.6000
# Epoch: 050, Train_Loss: 0.5586,Test_Loss: 0.7611,Train_f1: 0.7399,Test_f1: 0.5867,Train_acc: 0.7400,Test_acc: 0.5867
# Epoch: 051, Train_Loss: 0.5632,Test_Loss: 0.7605,Train_f1: 0.7399,Test_f1: 0.5791,Train_acc: 0.7400,Test_acc: 0.5800
# Epoch: 052, Train_Loss: 0.5650,Test_Loss: 0.7613,Train_f1: 0.7391,Test_f1: 0.5919,Train_acc: 0.7400,Test_acc: 0.5933
# Epoch: 053, Train_Loss: 0.5639,Test_Loss: 0.7616,Train_f1: 0.7596,Test_f1: 0.5982,Train_acc: 0.7600,Test_acc: 0.6000
# Epoch: 054, Train_Loss: 0.5617,Test_Loss: 0.7640,Train_f1: 0.6999,Test_f1: 0.5864,Train_acc: 0.7000,Test_acc: 0.5867
# Epoch: 055, Train_Loss: 0.5789,Test_Loss: 0.7785,Train_f1: 0.6486,Test_f1: 0.5717,Train_acc: 0.6600,Test_acc: 0.5867
# Epoch: 056, Train_Loss: 0.6039,Test_Loss: 0.7993,Train_f1: 0.6847,Test_f1: 0.5726,Train_acc: 0.7000,Test_acc: 0.5933
# Epoch: 057, Train_Loss: 0.6164,Test_Loss: 0.8082,Train_f1: 0.6604,Test_f1: 0.5783,Train_acc: 0.6800,Test_acc: 0.6000
# Epoch: 058, Train_Loss: 0.6113,Test_Loss: 0.8048,Train_f1: 0.6847,Test_f1: 0.5783,Train_acc: 0.7000,Test_acc: 0.6000
# Epoch: 059, Train_Loss: 0.5912,Test_Loss: 0.7887,Train_f1: 0.6847,Test_f1: 0.5670,Train_acc: 0.7000,Test_acc: 0.5867
# Epoch: 060, Train_Loss: 0.5781,Test_Loss: 0.7758,Train_f1: 0.6667,Test_f1: 0.5621,Train_acc: 0.6800,Test_acc: 0.5733
# Epoch: 061, Train_Loss: 0.5730,Test_Loss: 0.7689,Train_f1: 0.7182,Test_f1: 0.5509,Train_acc: 0.7200,Test_acc: 0.5533
# Epoch: 062, Train_Loss: 0.5702,Test_Loss: 0.7653,Train_f1: 0.7399,Test_f1: 0.5798,Train_acc: 0.7400,Test_acc: 0.5800
# Epoch: 063, Train_Loss: 0.5706,Test_Loss: 0.7652,Train_f1: 0.7997,Test_f1: 0.5467,Train_acc: 0.8000,Test_acc: 0.5467
# Epoch: 064, Train_Loss: 0.5734,Test_Loss: 0.7656,Train_f1: 0.7997,Test_f1: 0.5532,Train_acc: 0.8000,Test_acc: 0.5533
# Epoch: 065, Train_Loss: 0.5769,Test_Loss: 0.7655,Train_f1: 0.7799,Test_f1: 0.5463,Train_acc: 0.7800,Test_acc: 0.5467
# Epoch: 066, Train_Loss: 0.5784,Test_Loss: 0.7656,Train_f1: 0.7596,Test_f1: 0.5241,Train_acc: 0.7600,Test_acc: 0.5267
# Epoch: 067, Train_Loss: 0.5809,Test_Loss: 0.7683,Train_f1: 0.7348,Test_f1: 0.5130,Train_acc: 0.7400,Test_acc: 0.5200
# Epoch: 068, Train_Loss: 0.5863,Test_Loss: 0.7744,Train_f1: 0.6900,Test_f1: 0.5326,Train_acc: 0.7000,Test_acc: 0.5467
# Epoch: 069, Train_Loss: 0.5897,Test_Loss: 0.7786,Train_f1: 0.6847,Test_f1: 0.5556,Train_acc: 0.7000,Test_acc: 0.5733
# Epoch: 070, Train_Loss: 0.5900,Test_Loss: 0.7818,Train_f1: 0.7083,Test_f1: 0.5613,Train_acc: 0.7200,Test_acc: 0.5800
# Epoch: 071, Train_Loss: 0.5873,Test_Loss: 0.7807,Train_f1: 0.7083,Test_f1: 0.5694,Train_acc: 0.7200,Test_acc: 0.5867
# Epoch: 072, Train_Loss: 0.5792,Test_Loss: 0.7779,Train_f1: 0.7126,Test_f1: 0.5694,Train_acc: 0.7200,Test_acc: 0.5867
# Epoch: 073, Train_Loss: 0.5658,Test_Loss: 0.7700,Train_f1: 0.6940,Test_f1: 0.5520,Train_acc: 0.7000,Test_acc: 0.5600
# Epoch: 074, Train_Loss: 0.5593,Test_Loss: 0.7697,Train_f1: 0.7399,Test_f1: 0.5800,Train_acc: 0.7400,Test_acc: 0.5800
# Epoch: 075, Train_Loss: 0.5597,Test_Loss: 0.7721,Train_f1: 0.7792,Test_f1: 0.5919,Train_acc: 0.7800,Test_acc: 0.5933
# Epoch: 076, Train_Loss: 0.5601,Test_Loss: 0.7723,Train_f1: 0.7792,Test_f1: 0.5965,Train_acc: 0.7800,Test_acc: 0.6000
# Epoch: 077, Train_Loss: 0.5595,Test_Loss: 0.7700,Train_f1: 0.7792,Test_f1: 0.5982,Train_acc: 0.7800,Test_acc: 0.6000
# Epoch: 078, Train_Loss: 0.5575,Test_Loss: 0.7677,Train_f1: 0.7997,Test_f1: 0.5864,Train_acc: 0.8000,Test_acc: 0.5867
# Epoch: 079, Train_Loss: 0.5573,Test_Loss: 0.7675,Train_f1: 0.7997,Test_f1: 0.5929,Train_acc: 0.8000,Test_acc: 0.5933
# Epoch: 080, Train_Loss: 0.5561,Test_Loss: 0.7670,Train_f1: 0.7600,Test_f1: 0.5866,Train_acc: 0.7600,Test_acc: 0.5867
# Epoch: 081, Train_Loss: 0.5557,Test_Loss: 0.7677,Train_f1: 0.7399,Test_f1: 0.5864,Train_acc: 0.7400,Test_acc: 0.5867
# Epoch: 082, Train_Loss: 0.5571,Test_Loss: 0.7686,Train_f1: 0.7196,Test_f1: 0.5651,Train_acc: 0.7200,Test_acc: 0.5667
# Epoch: 083, Train_Loss: 0.5582,Test_Loss: 0.7707,Train_f1: 0.7196,Test_f1: 0.5643,Train_acc: 0.7200,Test_acc: 0.5667
# Epoch: 084, Train_Loss: 0.5598,Test_Loss: 0.7742,Train_f1: 0.7585,Test_f1: 0.5634,Train_acc: 0.7600,Test_acc: 0.5667
# Epoch: 085, Train_Loss: 0.5606,Test_Loss: 0.7763,Train_f1: 0.7374,Test_f1: 0.5561,Train_acc: 0.7400,Test_acc: 0.5600
# Epoch: 086, Train_Loss: 0.5606,Test_Loss: 0.7784,Train_f1: 0.7159,Test_f1: 0.5696,Train_acc: 0.7200,Test_acc: 0.5733
# Epoch: 087, Train_Loss: 0.5601,Test_Loss: 0.7800,Train_f1: 0.7159,Test_f1: 0.5819,Train_acc: 0.7200,Test_acc: 0.5867
# Epoch: 088, Train_Loss: 0.5601,Test_Loss: 0.7785,Train_f1: 0.7374,Test_f1: 0.5634,Train_acc: 0.7400,Test_acc: 0.5667
# Epoch: 089, Train_Loss: 0.5595,Test_Loss: 0.7764,Train_f1: 0.7391,Test_f1: 0.5848,Train_acc: 0.7400,Test_acc: 0.5867
# Epoch: 090, Train_Loss: 0.5587,Test_Loss: 0.7747,Train_f1: 0.7391,Test_f1: 0.5657,Train_acc: 0.7400,Test_acc: 0.5667
# Epoch: 091, Train_Loss: 0.5589,Test_Loss: 0.7744,Train_f1: 0.7391,Test_f1: 0.5657,Train_acc: 0.7400,Test_acc: 0.5667
# Epoch: 092, Train_Loss: 0.5602,Test_Loss: 0.7753,Train_f1: 0.7374,Test_f1: 0.5714,Train_acc: 0.7400,Test_acc: 0.5733
# Epoch: 093, Train_Loss: 0.5592,Test_Loss: 0.7785,Train_f1: 0.6940,Test_f1: 0.5684,Train_acc: 0.7000,Test_acc: 0.5733
# Epoch: 094, Train_Loss: 0.5540,Test_Loss: 0.7795,Train_f1: 0.7159,Test_f1: 0.5696,Train_acc: 0.7200,Test_acc: 0.5733
# Epoch: 095, Train_Loss: 0.5511,Test_Loss: 0.7806,Train_f1: 0.7159,Test_f1: 0.5572,Train_acc: 0.7200,Test_acc: 0.5600
# Epoch: 096, Train_Loss: 0.5482,Test_Loss: 0.7813,Train_f1: 0.7159,Test_f1: 0.5383,Train_acc: 0.7200,Test_acc: 0.5400
# Epoch: 097, Train_Loss: 0.5473,Test_Loss: 0.7818,Train_f1: 0.7159,Test_f1: 0.5446,Train_acc: 0.7200,Test_acc: 0.5467
# Epoch: 098, Train_Loss: 0.5477,Test_Loss: 0.7835,Train_f1: 0.6940,Test_f1: 0.5536,Train_acc: 0.7000,Test_acc: 0.5600
# Epoch: 099, Train_Loss: 0.5492,Test_Loss: 0.7855,Train_f1: 0.6940,Test_f1: 0.5520,Train_acc: 0.7000,Test_acc: 0.5600
# Epoch: 100, Train_Loss: 0.5521,Test_Loss: 0.7900,Train_f1: 0.6940,Test_f1: 0.5758,Train_acc: 0.7000,Test_acc: 0.5867
# Epoch: 101, Train_Loss: 0.5563,Test_Loss: 0.7959,Train_f1: 0.7126,Test_f1: 0.5601,Train_acc: 0.7200,Test_acc: 0.5733
# Epoch: 102, Train_Loss: 0.5604,Test_Loss: 0.7977,Train_f1: 0.7126,Test_f1: 0.5659,Train_acc: 0.7200,Test_acc: 0.5800
# Epoch: 103, Train_Loss: 0.5522,Test_Loss: 0.7897,Train_f1: 0.7126,Test_f1: 0.5758,Train_acc: 0.7200,Test_acc: 0.5867
# Epoch: 104, Train_Loss: 0.5456,Test_Loss: 0.7804,Train_f1: 0.7159,Test_f1: 0.5549,Train_acc: 0.7200,Test_acc: 0.5600
# Epoch: 105, Train_Loss: 0.5439,Test_Loss: 0.7741,Train_f1: 0.7391,Test_f1: 0.5795,Train_acc: 0.7400,Test_acc: 0.5800
# Epoch: 106, Train_Loss: 0.5471,Test_Loss: 0.7726,Train_f1: 0.7200,Test_f1: 0.5800,Train_acc: 0.7200,Test_acc: 0.5800
# Epoch: 107, Train_Loss: 0.5478,Test_Loss: 0.7726,Train_f1: 0.7399,Test_f1: 0.5800,Train_acc: 0.7400,Test_acc: 0.5800
# Epoch: 108, Train_Loss: 0.5469,Test_Loss: 0.7729,Train_f1: 0.7200,Test_f1: 0.5800,Train_acc: 0.7200,Test_acc: 0.5800
# Epoch: 109, Train_Loss: 0.5473,Test_Loss: 0.7739,Train_f1: 0.7196,Test_f1: 0.5665,Train_acc: 0.7200,Test_acc: 0.5667
# Epoch: 110, Train_Loss: 0.5493,Test_Loss: 0.7744,Train_f1: 0.6779,Test_f1: 0.5840,Train_acc: 0.6800,Test_acc: 0.5867
# Epoch: 111, Train_Loss: 0.5543,Test_Loss: 0.7774,Train_f1: 0.7126,Test_f1: 0.5621,Train_acc: 0.7200,Test_acc: 0.5733
# Epoch: 112, Train_Loss: 0.5571,Test_Loss: 0.7785,Train_f1: 0.7126,Test_f1: 0.5522,Train_acc: 0.7200,Test_acc: 0.5667
# Epoch: 113, Train_Loss: 0.5559,Test_Loss: 0.7768,Train_f1: 0.7126,Test_f1: 0.5543,Train_acc: 0.7200,Test_acc: 0.5667
# Epoch: 114, Train_Loss: 0.5548,Test_Loss: 0.7754,Train_f1: 0.6940,Test_f1: 0.5503,Train_acc: 0.7000,Test_acc: 0.5600
# Epoch: 115, Train_Loss: 0.5534,Test_Loss: 0.7742,Train_f1: 0.7159,Test_f1: 0.5671,Train_acc: 0.7200,Test_acc: 0.5733
# Epoch: 116, Train_Loss: 0.5520,Test_Loss: 0.7737,Train_f1: 0.6970,Test_f1: 0.5758,Train_acc: 0.7000,Test_acc: 0.5800
# Epoch: 117, Train_Loss: 0.5505,Test_Loss: 0.7737,Train_f1: 0.7391,Test_f1: 0.5643,Train_acc: 0.7400,Test_acc: 0.5667
# Epoch: 118, Train_Loss: 0.5495,Test_Loss: 0.7756,Train_f1: 0.7182,Test_f1: 0.5706,Train_acc: 0.7200,Test_acc: 0.5733
# Epoch: 119, Train_Loss: 0.5486,Test_Loss: 0.7758,Train_f1: 0.7391,Test_f1: 0.5580,Train_acc: 0.7400,Test_acc: 0.5600
# Epoch: 120, Train_Loss: 0.5478,Test_Loss: 0.7759,Train_f1: 0.7391,Test_f1: 0.5517,Train_acc: 0.7400,Test_acc: 0.5533
# Epoch: 121, Train_Loss: 0.5485,Test_Loss: 0.7774,Train_f1: 0.7182,Test_f1: 0.5561,Train_acc: 0.7200,Test_acc: 0.5600
# Epoch: 122, Train_Loss: 0.5508,Test_Loss: 0.7789,Train_f1: 0.7159,Test_f1: 0.5623,Train_acc: 0.7200,Test_acc: 0.5667
# Epoch: 123, Train_Loss: 0.5552,Test_Loss: 0.7812,Train_f1: 0.6940,Test_f1: 0.5699,Train_acc: 0.7000,Test_acc: 0.5800
# Epoch: 124, Train_Loss: 0.5576,Test_Loss: 0.7827,Train_f1: 0.7313,Test_f1: 0.5601,Train_acc: 0.7400,Test_acc: 0.5733
# Epoch: 125, Train_Loss: 0.5561,Test_Loss: 0.7819,Train_f1: 0.7126,Test_f1: 0.5699,Train_acc: 0.7200,Test_acc: 0.5800
# Epoch: 126, Train_Loss: 0.5511,Test_Loss: 0.7805,Train_f1: 0.7159,Test_f1: 0.5561,Train_acc: 0.7200,Test_acc: 0.5600
# Epoch: 127, Train_Loss: 0.5485,Test_Loss: 0.7803,Train_f1: 0.7391,Test_f1: 0.5726,Train_acc: 0.7400,Test_acc: 0.5733
# Epoch: 128, Train_Loss: 0.5497,Test_Loss: 0.7823,Train_f1: 0.7799,Test_f1: 0.5730,Train_acc: 0.7800,Test_acc: 0.5733
# Epoch: 129, Train_Loss: 0.5508,Test_Loss: 0.7862,Train_f1: 0.7596,Test_f1: 0.5662,Train_acc: 0.7600,Test_acc: 0.5667
# Epoch: 130, Train_Loss: 0.5527,Test_Loss: 0.7900,Train_f1: 0.7391,Test_f1: 0.5795,Train_acc: 0.7400,Test_acc: 0.5800
# Epoch: 131, Train_Loss: 0.5551,Test_Loss: 0.7946,Train_f1: 0.7391,Test_f1: 0.5795,Train_acc: 0.7400,Test_acc: 0.5800
# Epoch: 132, Train_Loss: 0.5569,Test_Loss: 0.7963,Train_f1: 0.7159,Test_f1: 0.5758,Train_acc: 0.7200,Test_acc: 0.5800
# Epoch: 133, Train_Loss: 0.5571,Test_Loss: 0.7962,Train_f1: 0.7126,Test_f1: 0.5536,Train_acc: 0.7200,Test_acc: 0.5600
# Epoch: 134, Train_Loss: 0.5556,Test_Loss: 0.7968,Train_f1: 0.7126,Test_f1: 0.5536,Train_acc: 0.7200,Test_acc: 0.5600
# Epoch: 135, Train_Loss: 0.5514,Test_Loss: 0.7950,Train_f1: 0.7391,Test_f1: 0.5657,Train_acc: 0.7400,Test_acc: 0.5667
# Epoch: 136, Train_Loss: 0.5501,Test_Loss: 0.7924,Train_f1: 0.7391,Test_f1: 0.5860,Train_acc: 0.7400,Test_acc: 0.5867
# Epoch: 137, Train_Loss: 0.5481,Test_Loss: 0.7923,Train_f1: 0.7596,Test_f1: 0.5733,Train_acc: 0.7600,Test_acc: 0.5733
# Epoch: 138, Train_Loss: 0.5472,Test_Loss: 0.7950,Train_f1: 0.8199,Test_f1: 0.5866,Train_acc: 0.8200,Test_acc: 0.5867
# Epoch: 139, Train_Loss: 0.5491,Test_Loss: 0.7975,Train_f1: 0.8199,Test_f1: 0.5974,Train_acc: 0.8200,Test_acc: 0.6000
# Epoch: 140, Train_Loss: 0.5503,Test_Loss: 0.7967,Train_f1: 0.8199,Test_f1: 0.5974,Train_acc: 0.8200,Test_acc: 0.6000
# Epoch: 141, Train_Loss: 0.5476,Test_Loss: 0.7934,Train_f1: 0.7997,Test_f1: 0.6116,Train_acc: 0.8000,Test_acc: 0.6133
# Epoch: 142, Train_Loss: 0.5467,Test_Loss: 0.7924,Train_f1: 0.7997,Test_f1: 0.5929,Train_acc: 0.8000,Test_acc: 0.5933
# Epoch: 143, Train_Loss: 0.5456,Test_Loss: 0.7887,Train_f1: 0.7799,Test_f1: 0.5933,Train_acc: 0.7800,Test_acc: 0.5933
# Epoch: 144, Train_Loss: 0.5454,Test_Loss: 0.7877,Train_f1: 0.7196,Test_f1: 0.5785,Train_acc: 0.7200,Test_acc: 0.5800
# Epoch: 145, Train_Loss: 0.5456,Test_Loss: 0.7889,Train_f1: 0.6970,Test_f1: 0.5892,Train_acc: 0.7000,Test_acc: 0.5933
# Epoch: 146, Train_Loss: 0.5433,Test_Loss: 0.7895,Train_f1: 0.6779,Test_f1: 0.5965,Train_acc: 0.6800,Test_acc: 0.6000
# Epoch: 147, Train_Loss: 0.5424,Test_Loss: 0.7915,Train_f1: 0.6970,Test_f1: 0.5965,Train_acc: 0.7000,Test_acc: 0.6000
# Epoch: 148, Train_Loss: 0.5414,Test_Loss: 0.7933,Train_f1: 0.6970,Test_f1: 0.5903,Train_acc: 0.7000,Test_acc: 0.5933
# Epoch: 149, Train_Loss: 0.5400,Test_Loss: 0.7940,Train_f1: 0.6989,Test_f1: 0.5911,Train_acc: 0.7000,Test_acc: 0.5933
# Epoch: 150, Train_Loss: 0.5381,Test_Loss: 0.7949,Train_f1: 0.7196,Test_f1: 0.5593,Train_acc: 0.7200,Test_acc: 0.5600
# Epoch: 151, Train_Loss: 0.5365,Test_Loss: 0.7948,Train_f1: 0.7196,Test_f1: 0.5593,Train_acc: 0.7200,Test_acc: 0.5600
# Epoch: 152, Train_Loss: 0.5354,Test_Loss: 0.7947,Train_f1: 0.7399,Test_f1: 0.5733,Train_acc: 0.7400,Test_acc: 0.5733
# Epoch: 153, Train_Loss: 0.5349,Test_Loss: 0.7937,Train_f1: 0.7799,Test_f1: 0.5867,Train_acc: 0.7800,Test_acc: 0.5867
# Epoch: 154, Train_Loss: 0.5344,Test_Loss: 0.7933,Train_f1: 0.7799,Test_f1: 0.5867,Train_acc: 0.7800,Test_acc: 0.5867
# Epoch: 155, Train_Loss: 0.5335,Test_Loss: 0.7918,Train_f1: 0.7399,Test_f1: 0.5866,Train_acc: 0.7400,Test_acc: 0.5867
# Epoch: 156, Train_Loss: 0.5351,Test_Loss: 0.7906,Train_f1: 0.7391,Test_f1: 0.5785,Train_acc: 0.7400,Test_acc: 0.5800
# Epoch: 157, Train_Loss: 0.5407,Test_Loss: 0.7934,Train_f1: 0.7313,Test_f1: 0.5503,Train_acc: 0.7400,Test_acc: 0.5600
# Epoch: 158, Train_Loss: 0.5447,Test_Loss: 0.7959,Train_f1: 0.7313,Test_f1: 0.5637,Train_acc: 0.7400,Test_acc: 0.5800
# Epoch: 159, Train_Loss: 0.5410,Test_Loss: 0.7939,Train_f1: 0.7126,Test_f1: 0.5699,Train_acc: 0.7200,Test_acc: 0.5800
# Epoch: 160, Train_Loss: 0.5395,Test_Loss: 0.7928,Train_f1: 0.7126,Test_f1: 0.5601,Train_acc: 0.7200,Test_acc: 0.5733
# Epoch: 161, Train_Loss: 0.5384,Test_Loss: 0.7911,Train_f1: 0.7126,Test_f1: 0.5601,Train_acc: 0.7200,Test_acc: 0.5733
# Epoch: 162, Train_Loss: 0.5360,Test_Loss: 0.7874,Train_f1: 0.7126,Test_f1: 0.5520,Train_acc: 0.7200,Test_acc: 0.5600
# Epoch: 163, Train_Loss: 0.5339,Test_Loss: 0.7847,Train_f1: 0.7182,Test_f1: 0.5903,Train_acc: 0.7200,Test_acc: 0.5933
# Epoch: 164, Train_Loss: 0.5342,Test_Loss: 0.7830,Train_f1: 0.7196,Test_f1: 0.5791,Train_acc: 0.7200,Test_acc: 0.5800
# Epoch: 165, Train_Loss: 0.5348,Test_Loss: 0.7839,Train_f1: 0.7799,Test_f1: 0.5733,Train_acc: 0.7800,Test_acc: 0.5733
# Epoch: 166, Train_Loss: 0.5358,Test_Loss: 0.7863,Train_f1: 0.7997,Test_f1: 0.5733,Train_acc: 0.8000,Test_acc: 0.5733
# Epoch: 167, Train_Loss: 0.5367,Test_Loss: 0.7906,Train_f1: 0.7997,Test_f1: 0.5911,Train_acc: 0.8000,Test_acc: 0.5933
# Epoch: 168, Train_Loss: 0.5370,Test_Loss: 0.7924,Train_f1: 0.7585,Test_f1: 0.5903,Train_acc: 0.7600,Test_acc: 0.5933
# Epoch: 169, Train_Loss: 0.5364,Test_Loss: 0.7929,Train_f1: 0.7374,Test_f1: 0.5819,Train_acc: 0.7400,Test_acc: 0.5867
# Epoch: 170, Train_Loss: 0.5337,Test_Loss: 0.7888,Train_f1: 0.7997,Test_f1: 0.5714,Train_acc: 0.8000,Test_acc: 0.5733
# Epoch: 171, Train_Loss: 0.5335,Test_Loss: 0.7839,Train_f1: 0.8199,Test_f1: 0.5866,Train_acc: 0.8200,Test_acc: 0.5867
# Epoch: 172, Train_Loss: 0.5340,Test_Loss: 0.7825,Train_f1: 0.8199,Test_f1: 0.5593,Train_acc: 0.8200,Test_acc: 0.5600
# Epoch: 173, Train_Loss: 0.5342,Test_Loss: 0.7830,Train_f1: 0.8000,Test_f1: 0.5714,Train_acc: 0.8000,Test_acc: 0.5733
# Epoch: 174, Train_Loss: 0.5348,Test_Loss: 0.7840,Train_f1: 0.7799,Test_f1: 0.5777,Train_acc: 0.7800,Test_acc: 0.5800
# Epoch: 175, Train_Loss: 0.5378,Test_Loss: 0.7868,Train_f1: 0.7778,Test_f1: 0.5954,Train_acc: 0.7800,Test_acc: 0.6000
# Epoch: 176, Train_Loss: 0.5419,Test_Loss: 0.7885,Train_f1: 0.7585,Test_f1: 0.6027,Train_acc: 0.7600,Test_acc: 0.6067
# Epoch: 177, Train_Loss: 0.5446,Test_Loss: 0.7862,Train_f1: 0.7391,Test_f1: 0.5714,Train_acc: 0.7400,Test_acc: 0.5733
# Epoch: 178, Train_Loss: 0.5471,Test_Loss: 0.7850,Train_f1: 0.7799,Test_f1: 0.5657,Train_acc: 0.7800,Test_acc: 0.5667
# Epoch: 179, Train_Loss: 0.5421,Test_Loss: 0.7860,Train_f1: 0.8000,Test_f1: 0.5662,Train_acc: 0.8000,Test_acc: 0.5667
# Epoch: 180, Train_Loss: 0.5416,Test_Loss: 0.7878,Train_f1: 0.8000,Test_f1: 0.5730,Train_acc: 0.8000,Test_acc: 0.5733
# Epoch: 181, Train_Loss: 0.5401,Test_Loss: 0.7885,Train_f1: 0.8199,Test_f1: 0.5798,Train_acc: 0.8200,Test_acc: 0.5800
# Epoch: 182, Train_Loss: 0.5378,Test_Loss: 0.7882,Train_f1: 0.8000,Test_f1: 0.5860,Train_acc: 0.8000,Test_acc: 0.5867
# Epoch: 183, Train_Loss: 0.5364,Test_Loss: 0.7891,Train_f1: 0.7585,Test_f1: 0.6108,Train_acc: 0.7600,Test_acc: 0.6133
# Epoch: 184, Train_Loss: 0.5348,Test_Loss: 0.7901,Train_f1: 0.7585,Test_f1: 0.5965,Train_acc: 0.7600,Test_acc: 0.6000
# Epoch: 185, Train_Loss: 0.5323,Test_Loss: 0.7912,Train_f1: 0.7348,Test_f1: 0.6077,Train_acc: 0.7400,Test_acc: 0.6133
# Epoch: 186, Train_Loss: 0.5285,Test_Loss: 0.7906,Train_f1: 0.7159,Test_f1: 0.5965,Train_acc: 0.7200,Test_acc: 0.6000
# Epoch: 187, Train_Loss: 0.5252,Test_Loss: 0.7896,Train_f1: 0.7585,Test_f1: 0.6052,Train_acc: 0.7600,Test_acc: 0.6067
# Epoch: 188, Train_Loss: 0.5239,Test_Loss: 0.7895,Train_f1: 0.8000,Test_f1: 0.5866,Train_acc: 0.8000,Test_acc: 0.5867
# Epoch: 189, Train_Loss: 0.5241,Test_Loss: 0.7901,Train_f1: 0.8199,Test_f1: 0.5733,Train_acc: 0.8200,Test_acc: 0.5733
# Epoch: 190, Train_Loss: 0.5248,Test_Loss: 0.7890,Train_f1: 0.8397,Test_f1: 0.5867,Train_acc: 0.8400,Test_acc: 0.5867
# Epoch: 191, Train_Loss: 0.5244,Test_Loss: 0.7867,Train_f1: 0.8199,Test_f1: 0.5932,Train_acc: 0.8200,Test_acc: 0.5933
# Epoch: 192, Train_Loss: 0.5255,Test_Loss: 0.7861,Train_f1: 0.7792,Test_f1: 0.5974,Train_acc: 0.7800,Test_acc: 0.6000
# Epoch: 193, Train_Loss: 0.5290,Test_Loss: 0.7881,Train_f1: 0.7313,Test_f1: 0.5776,Train_acc: 0.7400,Test_acc: 0.5867
# Epoch: 194, Train_Loss: 0.5348,Test_Loss: 0.7924,Train_f1: 0.7500,Test_f1: 0.5739,Train_acc: 0.7600,Test_acc: 0.5867
# Epoch: 195, Train_Loss: 0.5425,Test_Loss: 0.7980,Train_f1: 0.7500,Test_f1: 0.5637,Train_acc: 0.7600,Test_acc: 0.5800
# Epoch: 196, Train_Loss: 0.5395,Test_Loss: 0.7936,Train_f1: 0.7500,Test_f1: 0.5739,Train_acc: 0.7600,Test_acc: 0.5867
# Epoch: 197, Train_Loss: 0.5329,Test_Loss: 0.7867,Train_f1: 0.7313,Test_f1: 0.5776,Train_acc: 0.7400,Test_acc: 0.5867
# Epoch: 198, Train_Loss: 0.5286,Test_Loss: 0.7842,Train_f1: 0.7792,Test_f1: 0.6052,Train_acc: 0.7800,Test_acc: 0.6067
# Epoch: 199, Train_Loss: 0.5302,Test_Loss: 0.7858,Train_f1: 0.8397,Test_f1: 0.5800,Train_acc: 0.8400,Test_acc: 0.5800
# Epoch: 200, Train_Loss: 0.5336,Test_Loss: 0.7888,Train_f1: 0.7987,Test_f1: 0.5929,Train_acc: 0.8000,Test_acc: 0.5933
# Epoch: 201, Train_Loss: 0.5344,Test_Loss: 0.7890,Train_f1: 0.7987,Test_f1: 0.5982,Train_acc: 0.8000,Test_acc: 0.6000
# Epoch: 202, Train_Loss: 0.5337,Test_Loss: 0.7877,Train_f1: 0.7987,Test_f1: 0.6108,Train_acc: 0.8000,Test_acc: 0.6133
# Epoch: 203, Train_Loss: 0.5278,Test_Loss: 0.7810,Train_f1: 0.7997,Test_f1: 0.5800,Train_acc: 0.8000,Test_acc: 0.5800
# Epoch: 204, Train_Loss: 0.5266,Test_Loss: 0.7811,Train_f1: 0.7792,Test_f1: 0.6179,Train_acc: 0.7800,Test_acc: 0.6200
# Epoch: 205, Train_Loss: 0.5292,Test_Loss: 0.7852,Train_f1: 0.7537,Test_f1: 0.5776,Train_acc: 0.7600,Test_acc: 0.5867
# Epoch: 206, Train_Loss: 0.5282,Test_Loss: 0.7848,Train_f1: 0.7537,Test_f1: 0.5776,Train_acc: 0.7600,Test_acc: 0.5867
# Epoch: 207, Train_Loss: 0.5245,Test_Loss: 0.7809,Train_f1: 0.7596,Test_f1: 0.6179,Train_acc: 0.7600,Test_acc: 0.6200
# Epoch: 208, Train_Loss: 0.5247,Test_Loss: 0.7784,Train_f1: 0.7997,Test_f1: 0.5866,Train_acc: 0.8000,Test_acc: 0.5867
# Epoch: 209, Train_Loss: 0.5272,Test_Loss: 0.7799,Train_f1: 0.8193,Test_f1: 0.6198,Train_acc: 0.8200,Test_acc: 0.6200
# Epoch: 210, Train_Loss: 0.5266,Test_Loss: 0.7826,Train_f1: 0.8193,Test_f1: 0.6127,Train_acc: 0.8200,Test_acc: 0.6133
# Epoch: 211, Train_Loss: 0.5252,Test_Loss: 0.7843,Train_f1: 0.8397,Test_f1: 0.5929,Train_acc: 0.8400,Test_acc: 0.5933
# Epoch: 212, Train_Loss: 0.5245,Test_Loss: 0.7852,Train_f1: 0.8397,Test_f1: 0.5798,Train_acc: 0.8400,Test_acc: 0.5800
# Epoch: 213, Train_Loss: 0.5240,Test_Loss: 0.7857,Train_f1: 0.8000,Test_f1: 0.5866,Train_acc: 0.8000,Test_acc: 0.5867
# Epoch: 214, Train_Loss: 0.5269,Test_Loss: 0.7889,Train_f1: 0.7585,Test_f1: 0.5982,Train_acc: 0.7600,Test_acc: 0.6000
# Epoch: 215, Train_Loss: 0.5318,Test_Loss: 0.7954,Train_f1: 0.7126,Test_f1: 0.5776,Train_acc: 0.7200,Test_acc: 0.5867
# Epoch: 216, Train_Loss: 0.5396,Test_Loss: 0.8050,Train_f1: 0.7500,Test_f1: 0.5717,Train_acc: 0.7600,Test_acc: 0.5867
# Epoch: 217, Train_Loss: 0.5406,Test_Loss: 0.8085,Train_f1: 0.7500,Test_f1: 0.5694,Train_acc: 0.7600,Test_acc: 0.5867
# Epoch: 218, Train_Loss: 0.5366,Test_Loss: 0.8082,Train_f1: 0.7500,Test_f1: 0.5694,Train_acc: 0.7600,Test_acc: 0.5867
# Epoch: 219, Train_Loss: 0.5250,Test_Loss: 0.7987,Train_f1: 0.7126,Test_f1: 0.5852,Train_acc: 0.7200,Test_acc: 0.5933
# Epoch: 220, Train_Loss: 0.5190,Test_Loss: 0.7940,Train_f1: 0.7391,Test_f1: 0.6052,Train_acc: 0.7400,Test_acc: 0.6067
# Epoch: 221, Train_Loss: 0.5196,Test_Loss: 0.7953,Train_f1: 0.8193,Test_f1: 0.5997,Train_acc: 0.8200,Test_acc: 0.6000
# Epoch: 222, Train_Loss: 0.5246,Test_Loss: 0.7992,Train_f1: 0.8193,Test_f1: 0.6108,Train_acc: 0.8200,Test_acc: 0.6133
# Epoch: 223, Train_Loss: 0.5238,Test_Loss: 0.7988,Train_f1: 0.7987,Test_f1: 0.6108,Train_acc: 0.8000,Test_acc: 0.6133
# Epoch: 224, Train_Loss: 0.5178,Test_Loss: 0.7957,Train_f1: 0.7997,Test_f1: 0.5867,Train_acc: 0.8000,Test_acc: 0.5867
# Epoch: 225, Train_Loss: 0.5169,Test_Loss: 0.7961,Train_f1: 0.7596,Test_f1: 0.5965,Train_acc: 0.7600,Test_acc: 0.6000
# Epoch: 226, Train_Loss: 0.5232,Test_Loss: 0.7976,Train_f1: 0.7537,Test_f1: 0.5972,Train_acc: 0.7600,Test_acc: 0.6067
# Epoch: 227, Train_Loss: 0.5336,Test_Loss: 0.8042,Train_f1: 0.7313,Test_f1: 0.5473,Train_acc: 0.7400,Test_acc: 0.5667
# Epoch: 228, Train_Loss: 0.5384,Test_Loss: 0.8093,Train_f1: 0.7313,Test_f1: 0.5643,Train_acc: 0.7400,Test_acc: 0.5867
# Epoch: 229, Train_Loss: 0.5372,Test_Loss: 0.8086,Train_f1: 0.7313,Test_f1: 0.5726,Train_acc: 0.7400,Test_acc: 0.5933
# Epoch: 230, Train_Loss: 0.5300,Test_Loss: 0.8039,Train_f1: 0.7537,Test_f1: 0.5797,Train_acc: 0.7600,Test_acc: 0.5933
# Epoch: 231, Train_Loss: 0.5182,Test_Loss: 0.7987,Train_f1: 0.7585,Test_f1: 0.5965,Train_acc: 0.7600,Test_acc: 0.6000
# Epoch: 232, Train_Loss: 0.5144,Test_Loss: 0.7957,Train_f1: 0.7997,Test_f1: 0.5932,Train_acc: 0.8000,Test_acc: 0.5933
# Epoch: 233, Train_Loss: 0.5175,Test_Loss: 0.7963,Train_f1: 0.8397,Test_f1: 0.5866,Train_acc: 0.8400,Test_acc: 0.5867
# Epoch: 234, Train_Loss: 0.5265,Test_Loss: 0.8014,Train_f1: 0.7778,Test_f1: 0.5867,Train_acc: 0.7800,Test_acc: 0.5933
# Epoch: 235, Train_Loss: 0.5277,Test_Loss: 0.8016,Train_f1: 0.7565,Test_f1: 0.5732,Train_acc: 0.7600,Test_acc: 0.5800
# Epoch: 236, Train_Loss: 0.5300,Test_Loss: 0.8007,Train_f1: 0.7537,Test_f1: 0.5732,Train_acc: 0.7600,Test_acc: 0.5800
# Epoch: 237, Train_Loss: 0.5275,Test_Loss: 0.7964,Train_f1: 0.7987,Test_f1: 0.5819,Train_acc: 0.8000,Test_acc: 0.5867
# Epoch: 238, Train_Loss: 0.5239,Test_Loss: 0.7922,Train_f1: 0.8193,Test_f1: 0.5864,Train_acc: 0.8200,Test_acc: 0.5867
# Epoch: 239, Train_Loss: 0.5231,Test_Loss: 0.7903,Train_f1: 0.7997,Test_f1: 0.5733,Train_acc: 0.8000,Test_acc: 0.5733
# Epoch: 240, Train_Loss: 0.5245,Test_Loss: 0.7911,Train_f1: 0.7997,Test_f1: 0.5593,Train_acc: 0.8000,Test_acc: 0.5600
# Epoch: 241, Train_Loss: 0.5267,Test_Loss: 0.7927,Train_f1: 0.7799,Test_f1: 0.5580,Train_acc: 0.7800,Test_acc: 0.5600
# Epoch: 242, Train_Loss: 0.5297,Test_Loss: 0.7948,Train_f1: 0.8000,Test_f1: 0.5500,Train_acc: 0.8000,Test_acc: 0.5533
# Epoch: 243, Train_Loss: 0.5317,Test_Loss: 0.7964,Train_f1: 0.8000,Test_f1: 0.5375,Train_acc: 0.8000,Test_acc: 0.5400
# Epoch: 244, Train_Loss: 0.5338,Test_Loss: 0.7973,Train_f1: 0.7997,Test_f1: 0.5383,Train_acc: 0.8000,Test_acc: 0.5400
# Epoch: 245, Train_Loss: 0.5339,Test_Loss: 0.7970,Train_f1: 0.7799,Test_f1: 0.5312,Train_acc: 0.7800,Test_acc: 0.5333
# Epoch: 246, Train_Loss: 0.5330,Test_Loss: 0.7975,Train_f1: 0.7799,Test_f1: 0.5437,Train_acc: 0.7800,Test_acc: 0.5467
# Epoch: 247, Train_Loss: 0.5319,Test_Loss: 0.7963,Train_f1: 0.7799,Test_f1: 0.5390,Train_acc: 0.7800,Test_acc: 0.5400
# Epoch: 248, Train_Loss: 0.5305,Test_Loss: 0.7947,Train_f1: 0.8193,Test_f1: 0.5532,Train_acc: 0.8200,Test_acc: 0.5533
# Epoch: 249, Train_Loss: 0.5281,Test_Loss: 0.7930,Train_f1: 0.8193,Test_f1: 0.5666,Train_acc: 0.8200,Test_acc: 0.5667

# %%
import matplotlib.pyplot as plt

plt.plot(train_losses)
plt.plot(val_losses)
plt.show()
